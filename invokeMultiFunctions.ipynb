# %%
from multiFunctions import multiFunctions

# %%
multiFunctions.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
multiFunctions.OddEven()
# Out:
# Enter a number:  25
# 25  is Odd number

# %%
multiFunctions.Elegible()
# Out:
# Enter Your Gender:  Male
# Enter Your Age:  63
# Your Gender :  Male
# Your Age :  63
# ELIGIBLE

# %%
multiFunctions.percentage()
# Out:
# Enter Your Subject1 Mark:  54
# Enter Your Subject2 Mark:  58
# Enter Your Subject3 Mark:  69
# Enter Your Subject4 Mark:  75
# Enter Your Subject5 Mark:  85
# Subject1 :  54
# Subject2 :  58
# Subject3 :  69
# Subject4 :  75
# Subject5 :  85
# Total :  341
# Percentage :  68.2

# %%
multiFunctions.triangle()
# Out:
# Enter Area Height Value :  32
# Enter Area  Breadth Value :  34
# Enter Perimeter Height1 Value:  2
# Enter Perimeter Height2 Value:  4
# Enter Perimeter Breadth Value:  4
# Height :  32
# Breadth :  34
# Area of Triangle :  544.0
# Height1 :  2
# Subject4 :  4
# Height2 :  4
# Perimeter of Triangle :  10
